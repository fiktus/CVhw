# %% [markdown]
# <h3 style="text-align: center;"><b>Школа глубокого обучения ФПМИ МФТИ</b></h3>
#
# <h3 style="text-align: center;"><b>Домашнее задание. Классификация изображений</b></h3>

# %% [markdown]
# ![dls.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # Домашнее задание. Классификация изображений
#
# Сегодня вам предстоить помочь телекомпании FOX в обработке их контента. Как вы знаете, сериал "Симпсоны" идет на телеэкранах более 25 лет, и за это время скопилось очень много видеоматериала. Персоонажи менялись вместе с изменяющимися графическими технологиями, и Гомер Симпсон-2018 не очень похож на Гомера Симпсона-1989. В этом задании вам необходимо классифицировать персонажей, проживающих в Спрингфилде. Думаю, нет смысла представлять каждого из них в отдельности.

# %% [markdown]
# В нашем тесте будет 991 картинка, для которых вам будет необходимо предсказать класс.

# %% [markdown]
# # kaggle nikname - Semen

# %% [markdown]
# # kaggle team - Семён_Фурсов_1171677680

# %% [markdown]
# для удобства результат написал в самом низу

# %% [markdown]
# ## Шаг 1. Установка зависимостей

# %% [markdown]
# ####Установим необходимые библиотеки и проверим доступность CUDA

# %%
# we will verify that GPU is enabled for this notebook
# following should print: CUDA is available!  Training on GPU ...
#
# if it prints otherwise, then you need to enable GPU:
# from Menu > Runtime > Change Runtime Type > Hardware Accelerator > GPU

import torch
import numpy as np
import copy

train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %%
# !nvidia-smi
# Out:
# Thu Apr 30 17:42:25 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.105.08             Driver Version: 580.105.08     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8             10W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   46C    P8             11W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import pickle
import numpy as np
from skimage import io

from tqdm import tqdm, tqdm_notebook
from PIL import Image
from pathlib import Path

from torchvision import transforms
from torchvision.transforms import v2

import torchsummary

from multiprocessing.pool import ThreadPool
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn

from matplotlib import colors, pyplot as plt
# %matplotlib inline

# в sklearn не все гладко, чтобы в colab удобно выводить картинки
# мы будем игнорировать warnings
import warnings
warnings.filterwarnings(action='ignore', category=DeprecationWarning)

# %% [markdown]
# #### Проверим версии Python и библиотек
# Посмотрим, какие версии установлены:

# %%
# !python --version
from importlib.metadata import version
for b in ['torch', 'torchvision', 'tqdm', 'matplotlib', 'seaborn', 'Pillow']:
    print(b + ' version: '+ version(b))
# Out:
# Python 3.12.12
# torch version: 2.10.0+cu128
# torchvision version: 0.25.0+cu128
# tqdm version: 4.67.3
# matplotlib version: 3.10.0
# seaborn version: 0.13.2
# Pillow version: 11.3.0

# %% [markdown]
# Сверим с версиями питона и библиотек, на которых работал эталонный ноутбук:
#
# - Python 3.12.12
# - torch version: 2.8.0+cu126
# - torchvision version: 0.23.0+cu126
# - tqdm version: 4.67.1
# - matplotlib version: 3.10.0
# - seaborn version: 0.13.2
# - Pillow version: 11.3.0

# %% [markdown]
#  #### Определим константы, которые будем использовать в по ходу ноутбука

# %%
# разные режимы датасета
DATA_MODES = ['train', 'val', 'test']

# работаем на видеокарте
DEVICE = torch.device("cuda")

#определим директории с тренировочными и тестовыми файлами
TRAIN_DIR = Path('/kaggle/working/train') #Path('./data/train/')
TEST_DIR = Path('/kaggle/working/testset') #Path('./data/testset')

# параметры нормировки изображений по трем каналам перед подачей в модель
NORMALIZE_MEAN = [0.485, 0.456, 0.406]
NORMALIZE_STD = [0.229, 0.224, 0.225]

# все изображения будут масштабированы к размеру 224x224 px
RESCALE_SIZE = [224, 224]

# %% [markdown]
# ## Шаг 2. Загрузка и обработка данных

# %% [markdown]
# #### Скачаем изображения по ссылке

# %%
# !gdown 1RxBQiZgRAfio2tWhEE7lzZ6IaJzLheH1
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1RxBQiZgRAfio2tWhEE7lzZ6IaJzLheH1
# From (redirected): https://drive.google.com/uc?id=1RxBQiZgRAfio2tWhEE7lzZ6IaJzLheH1&confirm=t&uuid=389e72e0-d6c6-46aa-a9c2-cd2f3e881cd3
# To: /kaggle/working/journey-springfield.zip
# 100%|█████████████████████████████████████████| 546M/546M [00:04<00:00, 113MB/s]

# %%
# !unzip -q /kaggle/working/journey-springfield.zip

# %% [markdown]
# Посмотрите на структуру файлов в папках train и testset.
#
# В train лежат данные, которые мы будем использовать для обучения модели. Изображения персонажей разложены по папкам, которые названы по именам персонажей. Названия папок мы в дальнейшем будет использовать в качестве текстовых меток классов.
#
# В testset находятся изображения, для которых вам надо будет сделать прогноз наиболее вероятного класса.

# %% [markdown]
# Для обращения к файлам сформируем списки имен файлов обучающей+валидационнной и тестовой выборок. Это полные имена, включающие путь к файлам.

# %%
train_val_files = sorted(list(TRAIN_DIR.rglob('*.jpg')))
test_files = sorted(list(TEST_DIR.rglob('*.jpg')))

# %%
train_val_files
# Out:
# [PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0000.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0001.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0002.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0003.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0004.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0005.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0006.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0007.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0008.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0009.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0010.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0011.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0012.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0013.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0014.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0015.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0016.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0017.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0018.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0019.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0020.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0021.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0022.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0023.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0024.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0025.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0026.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0027.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0028.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0029.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0030.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0031.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0032.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0033.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0034.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0035.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0036.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0037.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0038.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0039.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0040.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0041.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0042.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0043.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0044.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0045.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0046.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0047.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0048.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0049.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0050.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0051.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0052.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0053.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0054.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0055.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0056.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0057.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0058.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0059.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0060.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0061.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0062.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0063.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0064.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0065.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0066.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0067.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0068.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0069.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0070.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0071.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0072.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0073.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0074.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0075.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0076.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0077.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0078.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0079.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0080.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0081.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0082.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0083.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0084.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0085.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0086.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0087.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0088.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0089.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0090.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0091.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0092.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0093.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0094.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0095.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0096.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0097.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0098.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0099.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0100.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0101.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0102.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0103.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0104.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0105.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0106.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0107.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0108.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0109.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0110.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0111.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0112.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0113.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0114.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0115.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0116.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0117.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0118.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0119.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0120.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0121.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0122.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0123.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0124.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0125.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0126.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0127.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0128.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0129.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0130.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0131.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0132.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0133.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0134.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0135.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0136.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0137.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0138.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0139.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0140.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0141.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0142.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0143.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0144.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0145.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0146.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0147.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0148.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0149.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0150.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0151.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0152.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0153.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0154.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0155.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0156.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0157.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0158.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0159.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0160.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0161.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0162.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0163.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0164.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0165.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0166.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0167.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0168.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0169.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0170.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0171.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0172.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0173.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0174.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0175.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0176.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0177.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0178.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0179.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0180.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0181.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0182.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0183.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0184.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0185.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0186.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0187.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0188.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0189.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0190.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0191.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0192.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0193.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0194.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0195.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0196.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0197.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0198.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0199.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0200.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0201.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0202.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0203.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0204.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0205.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0206.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0207.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0208.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0209.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0210.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0211.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0212.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0213.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0214.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0215.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0216.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0217.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0218.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0219.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0220.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0221.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0222.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0223.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0224.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0225.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0226.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0227.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0228.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0229.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0230.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0231.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0232.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0233.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0234.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0235.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0236.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0237.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0238.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0239.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0240.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0241.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0242.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0243.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0244.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0245.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0246.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0247.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0248.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0249.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0250.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0251.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0252.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0253.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0254.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0255.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0256.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0257.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0258.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0259.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0260.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0261.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0262.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0263.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0264.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0265.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0266.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0267.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0268.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0269.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0270.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0271.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0272.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0273.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0274.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0275.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0276.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0277.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0278.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0279.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0280.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0281.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0282.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0283.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0284.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0285.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0286.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0287.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0288.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0289.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0290.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0291.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0292.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0293.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0294.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0295.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0296.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0297.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0298.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0299.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0300.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0301.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0302.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0303.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0304.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0305.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0306.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0307.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0308.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0309.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0310.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0311.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0312.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0313.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0314.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0315.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0316.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0317.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0318.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0319.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0320.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0321.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0322.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0323.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0324.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0325.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0326.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0327.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0328.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0329.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0330.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0331.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0332.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0333.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0334.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0335.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0336.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0337.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0338.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0339.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0340.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0341.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0342.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0343.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0344.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0345.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0346.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0347.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0348.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0349.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0350.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0351.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0352.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0353.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0354.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0355.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0356.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0357.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0358.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0359.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0360.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0361.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0362.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0363.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0364.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0365.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0366.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0367.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0368.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0369.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0370.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0371.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0372.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0373.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0374.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0375.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0376.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0377.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0378.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0379.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0380.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0381.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0382.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0383.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0384.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0385.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0386.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0387.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0388.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0389.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0390.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0391.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0392.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0393.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0394.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0395.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0396.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0397.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0398.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0399.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0400.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0401.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0402.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0403.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0404.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0405.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0406.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0407.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0408.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0409.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0410.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0411.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0412.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0413.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0414.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0415.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0416.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0417.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0418.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0419.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0420.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0421.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0422.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0423.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0424.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0425.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0426.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0427.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0428.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0429.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0430.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0431.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0432.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0433.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0434.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0435.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0436.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0437.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0438.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0439.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0440.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0441.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0442.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0443.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0444.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0445.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0446.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0447.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0448.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0449.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0450.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0451.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0452.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0453.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0454.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0455.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0456.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0457.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0458.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0459.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0460.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0461.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0462.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0463.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0464.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0465.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0466.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0467.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0468.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0469.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0470.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0471.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0472.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0473.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0474.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0475.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0476.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0477.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0478.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0479.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0480.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0481.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0482.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0483.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0484.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0485.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0486.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0487.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0488.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0489.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0490.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0491.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0492.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0493.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0494.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0495.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0496.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0497.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0498.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0499.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0500.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0501.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0502.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0503.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0504.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0505.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0506.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0507.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0508.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0509.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0510.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0511.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0512.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0513.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0514.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0515.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0516.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0517.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0518.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0519.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0520.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0521.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0522.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0523.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0524.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0525.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0526.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0527.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0528.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0529.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0530.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0531.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0532.jpg'),
# ...
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0819.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0820.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0821.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0822.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0823.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0824.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0825.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0826.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0827.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0828.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0829.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0830.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0831.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0832.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0833.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0834.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0835.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0836.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0837.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0838.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0839.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0840.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0841.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0842.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0843.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0844.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0845.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0846.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0847.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0848.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0849.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0850.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0851.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0852.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0853.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0854.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0855.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0856.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0857.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0858.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0859.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0860.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0861.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0862.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0863.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0864.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0865.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0866.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0867.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0868.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0869.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0870.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0871.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0872.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0873.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0874.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0875.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0876.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0877.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0878.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0879.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0880.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0881.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0882.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0883.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0884.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0885.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0886.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0887.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0888.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0889.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0890.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0891.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0892.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0893.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0894.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0895.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0896.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0897.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0898.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0899.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0900.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0901.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0902.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0903.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0904.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0905.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0906.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0907.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0908.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0909.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0910.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0911.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/abraham_grampa_simpson/pic_0912.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0000.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0001.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0002.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0003.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0004.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0005.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0006.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0007.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0008.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0009.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0010.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0011.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0012.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0013.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0014.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0015.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0016.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0017.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0018.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0019.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0020.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0021.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0022.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0023.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0024.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0025.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0026.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0027.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0028.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0029.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0030.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0031.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0032.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0033.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0034.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0035.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0036.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0037.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0038.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0039.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0040.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/agnes_skinner/pic_0041.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0000.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0001.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0002.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0003.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0004.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0005.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0006.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0007.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0008.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0009.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0010.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0011.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0012.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0013.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0014.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0015.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0016.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0017.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0018.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0019.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0020.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0021.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0022.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0023.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0024.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0025.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0026.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0027.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0028.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0029.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0030.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0031.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0032.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0033.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0034.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0035.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0036.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0037.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0038.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0039.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0040.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0041.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0042.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0043.jpg'),
#  PosixPath('/kaggle/working/train/simpsons_dataset/apu_nahasapeemapetilon/pic_0044.jpg'),
#  ...]

# %% [markdown]
# Кодировать имена персонажей в числовые метки класса и обратно будем при помощи `LabelEncoder`.
#
# Для train выборки сформируем список текстовых меток всех изображений - имя родительской директории, которая одновременно является и именем персонажа. Зададим числовые метки классов нашего энкодера при помощи метода `fit`.
#
# Далее будем применять метод `transform` для преобразования текстовых меток в числовые, и метод `inverse_transform` для преобразования числовых меток в текстовые.

# %%
label_encoder = LabelEncoder()

train_val_labels = [path.parent.name for path in train_val_files]

label_encoder.fit(train_val_labels)
# Out:
# LabelEncoder()

# %% [markdown]
# Разделим train выборку на обучающую и валидационнную части. Для того, чтобы персонажи были пропорционально представлены в обучающей и валидационнной подвыборках, применим стратификацию по меткам класса.

# %%
from sklearn.model_selection import train_test_split

train_files, val_files = train_test_split(train_val_files, test_size=0.25, \
                                          stratify=train_val_labels)

# %% [markdown]
# ####Создадим Datasets и Dataloaders

# %% [markdown]
# Полезная статья, которой мы вдохновились при создании класса `SimpsonsDataset`:
# https://jhui.github.io/2018/02/09/PyTorch-Data-loading-preprocess_torchvision/

# %% [markdown]
# У нас есть набор файлов-картинок, которые требуется преобразовать в тензоры, и добавить к ним числовые метки классов. Реализуем это с помощью созданного нами класса `SimpsonsDataset`, который из списка файлов создаст необходимый нам Dataset.
#
# Будем действовать согласно инструкции из документации (https://docs.pytorch.org/tutorials/beginner/basics/data_tutorial.html#creating-a-custom-dataset-for-your-files):
# - наш класс будет наследовать от класса Dataset
# - мы переопределим методы `__init__`, `__len__` и `__getitem__`, а также для удобства добавим несколько методов для загрузки и преобразования изображений.

# %% [markdown]
# Важно разобраться, что делает метод self.transform_images_to_tensors().
#
# `Compose` объединяет последовательность следующих преобразований:
# - `PILToTensor` конвертирует  `PIL Image` в тензор с параметрами в диапазоне $[0, 255]$ (как все пиксели в исходном изображении)
# - `ToDtype` преобразует тензор в `FloatTensor` размера ($C \times H \times W$) со значениями пикселей в диапазоне $[0,1]$
# - затем `Normalize` производится масштабирование:
# $\text{input} = \frac{\text{input} - \text{mean}}{\text{std}} $, <br>      где константы mean и std - средние и дисперсии по каналам в датасете ImageNet
# - наконец, `Resize` преобразует картинки к размеру $224 \times 224$ (в описании датасета указано, что картинки разного размера, так как брались напрямую с видео, поэтому следует привести их к одному размеру).
#
# **
#
# Сейчас аугментация не изображений не производится, поэтому для обучающих и валидационных/тестовых изображений производится одинаковая трансформация. В дальнейшем, если вы захотите добавить аугментацию, вы можете сделать это, например, модифицировав метод `transform_images_to_tensors`. Подробнее про трансформацию изображений вы можете почитать в документации: https://docs.pytorch.org/vision/main/transforms.html
#
# **

# %%
class SimpsonsDataset(Dataset):
    def __init__(self, files, label_encoder, mode):
        super().__init__()
        # список файлов для загрузки
        self.files = sorted(files)
        # режим работы
        self.mode = mode
        if self.mode not in DATA_MODES:
            print(f"{self.mode} is not correct; correct modes: {DATA_MODES}")
            raise NameError

        self.label_encoder = label_encoder
        self.len_ = len(self.files)

    def __len__(self):
        return self.len_ # сейчас self.__len__() возвращает количество картинок, подаваемых на вход.
        # Если вы решите перевзвесить размеры категорий внутри класса -
        # не забудьте изменить вывод self.__len__()

        #oversampling (дублирование редкого класса) (чтобы редкие категории встречались чаще)

    def __getitem__(self, index):
        x = self.load_image(self.files[index])
        x = self.transform_images_to_tensors(x)

        if self.mode == 'test':
            return x
        else:
            path = self.files[index]
            y = self.label_encoder.transform([path.parent.name,]).item()
            return x, y

    # принимает путь к файлу изображения и возвращает само изображение
    def load_image(self, file):
        image = Image.open(file)
        image.load()
        return image

    # преобразует изображение в тензор
    def transform_images_to_tensors(self, image):
      if self.mode == 'train':

          #встроена аугментация
        transform = v2.Compose([
            v2.Resize(RESCALE_SIZE),
            v2.ColorJitter(brightness = 0.1, contrast = 0.1, saturation = 0.1), # изменить на 0.1 или ещё больше упростить
            v2.RandomHorizontalFlip(0.5),
            v2.RandomRotation(degrees=10),
            v2.PILToTensor(),
            v2.ToDtype(torch.float32, scale=True),
            v2.Normalize(NORMALIZE_MEAN, NORMALIZE_STD),
            #v2.RandomErasing(p=0.1),#области / попробовать убрать, упростить остальные параметры.
            

          ])
      else:
        transform = v2.Compose([
            v2.Resize(RESCALE_SIZE),
            v2.PILToTensor(),
            v2.ToDtype(torch.float32, scale=True),
            v2.Normalize(NORMALIZE_MEAN, NORMALIZE_STD),
            
          ])

      tensor_transformed = transform(image)
      return(tensor_transformed)

# %%
train_dataset = SimpsonsDataset(train_files, label_encoder = label_encoder, mode='train')
val_dataset = SimpsonsDataset(val_files, label_encoder, mode='val')

# %%
batch_size = 64 #маленький батчсайз, Чтобы не пришлось шаманить в сохранением весов для избежания переполнения памяти

# %%
train_dataset[0][0].shape
# Out:
# torch.Size([3, 224, 224])

# %% [markdown]
# # Реализация оверсемплинга, чтобы улучшить результат на малочисленных классах

# %%
from sklearn.utils.class_weight import compute_class_weight
from torch.utils.data import WeightedRandomSampler

train_labels_numeric = []

for i in range(len(train_dataset)):
    file_path = train_dataset.files[i]
    class_name = Path(file_path).parent.name
    label = train_dataset.label_encoder.transform([class_name]).item()
    train_labels_numeric.append(label)
    
class_weights = compute_class_weight('balanced', classes=np.unique(train_labels_numeric), y=train_labels_numeric)
class_weights = torch.tensor(class_weights, dtype=torch.float32).to(DEVICE)
sample_weights = class_weights[train_labels_numeric].cpu()
samp = WeightedRandomSampler( weights = sample_weights, num_samples = len(train_labels_numeric), replacement = True  )

# %%
train_loader = DataLoader(train_dataset, batch_size=batch_size, sampler=samp, num_workers=4, pin_memory=True, prefetch_factor=3)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers= 4, pin_memory=True, prefetch_factor=3)
loaders = {'train':train_loader, 'val': val_loader}

# %% [markdown]
# #### Посмотрим на изображения персонажей

# %% [markdown]
# Напишем функцию для визуализации картинок. Это аналог Imshow, которая будет принимать на вход тензоры

# %%
def imshow(inp, title=None, plt_ax=plt, default=False):
    """Imshow для тензоров"""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt_ax.imshow(inp)
    if title is not None:
        plt_ax.set_title(title)
    plt_ax.grid(False)

# %% [markdown]
# Проверим, как работает наша функция. Возьмем один батч из лоадера и подадим на вход функции первый тензор из этого батча. Заодно посмотрим, как работает кодировщик меток класса.

# %%
#image_tensor, label = next(iter(train_loader))
#print(f"Числовая метка класса: {label[0]}")
#print(f"Текстовая метка класса: {label_encoder.inverse_transform([label[0],])}")
#imshow(image_tensor[0])

# %%
# uncomment if you have problem with pillow
# def register_extension(id, extension): Image.EXTENSION[extension.lower()] = id.upper()
# Image.register_extension = register_extension
# def register_extensions(id, extensions):
#     for extension in extensions: register_extension(id, extension)
# Image.register_extensions = register_extensions

# %% [markdown]
# Давайте посмотрим на наших героев внутри датасета.

# %%
def show_images(n_rows, n_cols, dataset):
  # функция выводит изображения в n_rows рядов и n_cols столбцов
  fig, ax = plt.subplots(nrows=n_rows, ncols=n_cols, figsize=(n_cols * 4, n_rows * 4), \
                        sharey=True, sharex=True)

  for fig_x in ax.flatten(): # цикл повторяется (n_rows * n_cols) раз
    random_characters = int(np.random.uniform(0, len(dataset))) # берем случайное число в диапазоне [0; len(dataset))
    im_val, label = dataset[random_characters] # получаем изображение (тензорная форма)
    img_label = " ".join(map(lambda x: x.capitalize(), \
                             label_encoder.inverse_transform([label])[0].split('_')))  # числовую метку класса преобразуем в текстовую и немного отформатируем
    imshow(im_val.data.cpu(), title=img_label, plt_ax=fig_x) # отобразим изображение и метку класса с помощью написанной ранее функции imshow()
    fig_x.set_axis_off()
  return None

# %% [markdown]
# /
#
#
#
# ****!** Обратите внимание, что возможно, датасет требует дополнительной фильтрации, так как лейблы не всегда точно соответствуют картинкам. Очистка датасета - это один из способов повысить качество модели. Этим можно будет заняться во второй части домашнего задания. Запустим написанную функцию.**
# **
#
#
# /

# %%
show_images(n_rows = 3, n_cols = 4, dataset = val_dataset)

# %% [markdown]
# ## Шаг 3. Построение нейросети
#
# Запустить данную сеть будет вашим мини-заданием на первую неделю, чтобы было проще участвовать в соревновании.
#
# Данная архитектура будет очень простой и нужна для того, чтобы установить базовое понимание и получить простенький сабмит на Kaggle.
#
# О том, как работают свёртки подробней можно прочитать в документации Pytorch на функцию `Conv2d`:
#
# https://pytorch.org/docs/stable/generated/torch.nn.Conv2d.html
#
# Калькулятор свёрток:
#
# https://madebyollin.github.io/convnet-calculator/

# %% [markdown]
# #### Модель

# %%
class SimpleCnn(nn.Module):
    """
    Очень простая сверточная нейронная сеть для классификации изображений.

    Эта сеть состоит из пяти сверточных слоев, каждый из которых
    включает в себя операцию свертки, функцию активации ReLU и операцию
    пулинга (max-pooling). На выходе используется полносвязный слой
    для классификации на заданное количество классов.

    Параметры:
    ----------
    n_classes : int
        Количество классов для классификации.

    Примечание:
    ----------
    Входные изображения должны иметь размерность (3, H, W), где
    3 - слои rgb для цветной картинки, а H и W - высота и ширина изображения,
    соответственно. Размер выходного тензора будет равен (n_classes).

    Методы:
    -------
    forward(x):
        Пропускает входные данные через сеть и возвращает логиты для
        каждого класса.
    """

    def __init__(self, n_classes):
        super().__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=8, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
            nn.Dropout2d(p=0.3)
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
            nn.Dropout2d(p=0.3)
        )
        self.conv3 = nn.Sequential(
            nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
            nn.Dropout2d(p=0.3)
        )
        self.conv4 = nn.Sequential(
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
            nn.Dropout2d(p=0.3)
        )
        self.conv5 = nn.Sequential(
            nn.Conv2d(in_channels=64, out_channels=96, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
            nn.Dropout2d(p=0.3)
        )

        
        self.dropout = nn.Dropout(p=0.3)  
        self.out = nn.Linear(96 * 5 * 5, n_classes)


    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.conv5(x)

        x = x.view(x.size(0), -1)
        x = self.dropout(x)
        logits = self.out(x)
        return logits

# %% [markdown]
# *Описание слоев*:
#
# 1. размерность входа: $3\times 224 \times 224$
# 2. размерность после 1-го слоя (Conv2d + ReLU + MaxPool2d):  $8 \times 111 \times 111$
# 3. после 2-го слоя: $16 \times 54 \times 54$
# 4. после 3-го слоя: $32 \times 26 \times 26$
# 5. после 4-го слоя: $64 \times 12 \times 12$
# 6. после 5-го слоя: $96 \times 5 \times 5$
# 7. после полносвязного слоя (выход модели): количество классов

# %%
len(np.unique(train_val_labels))
# Out:
# 42

# %% [markdown]
# # Реализация архитектуры с skipconnections

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class SimpleCnn2(nn.Module):
    def __init__(self, n_classes, dropout_rate=0.20):
        super().__init__()

        # Первый блок должен быть без residual connection
        self.conv_block1 = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.Conv2d(32, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            nn.Dropout2d(dropout_rate)
        )
        

        self.conv_block2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            nn.Dropout2d(dropout_rate)
        )
        
        # Shortcut для второго блока 
        self.shortcut2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=1, stride=2),
            nn.BatchNorm2d(64)
        )

        self.conv_block3 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            nn.Dropout2d(dropout_rate)
        )
        
        # Shortcut для третьего блока
        self.shortcut3 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=1, stride=2),
            nn.BatchNorm2d(128)
        )

        self.conv_block4 = nn.Sequential(
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            nn.Dropout2d(dropout_rate)
        )
        
        # Shortcut для четвертого блока
        self.shortcut4 = nn.Sequential(
            nn.Conv2d(128, 256, kernel_size=1, stride=2),
            nn.BatchNorm2d(256)
        )

        self.conv_block5 = nn.Sequential(
            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            nn.Dropout2d(dropout_rate)
        )
        
        # Shortcut для пятого блока
        self.shortcut5 = nn.Sequential(
            nn.Conv2d(256, 512, kernel_size=1, stride=2),
            nn.BatchNorm2d(512)
        )
        
        self.global_avg_pool = nn.AdaptiveAvgPool2d((1, 1))
        
        self.classifier = nn.Sequential(
            nn.Dropout(dropout_rate),
            nn.Linear(512, 256),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout_rate),
            nn.Linear(256, n_classes)
        )
        
    def forward(self, x):
        # Первый блок
        x = self.conv_block1(x)
        
        # Второй блок 
        identity = x
        x = self.conv_block2(x)
        x = x + self.shortcut2(identity)
        x = F.relu(x)
        
        # Третий блок 
        identity = x
        x = self.conv_block3(x)
        x = x + self.shortcut3(identity)
        x = F.relu(x)
        
        # Четвертый блок 
        identity = x
        x = self.conv_block4(x)
        x = x + self.shortcut4(identity)
        x = F.relu(x)
        
        # Пятый блок 
        identity = x
        x = self.conv_block5(x)
        x = x + self.shortcut5(identity)
        x = F.relu(x)

        #классификация, global avg нужен для усреднения каналов карт
        x = self.global_avg_pool(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        
        return x

# %%
model_simple_cnn = SimpleCnn2(n_classes = len(np.unique(train_val_labels))).to(DEVICE)

torchsummary.summary(model_simple_cnn, (3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 224, 224]             896
#        BatchNorm2d-2         [-1, 32, 224, 224]              64
#               ReLU-3         [-1, 32, 224, 224]               0
#             Conv2d-4         [-1, 32, 224, 224]           9,248
#        BatchNorm2d-5         [-1, 32, 224, 224]              64
#               ReLU-6         [-1, 32, 224, 224]               0
#          MaxPool2d-7         [-1, 32, 112, 112]               0
#          Dropout2d-8         [-1, 32, 112, 112]               0
#             Conv2d-9         [-1, 64, 112, 112]          18,496
#       BatchNorm2d-10         [-1, 64, 112, 112]             128
#              ReLU-11         [-1, 64, 112, 112]               0
#            Conv2d-12         [-1, 64, 112, 112]          36,928
#       BatchNorm2d-13         [-1, 64, 112, 112]             128
#              ReLU-14         [-1, 64, 112, 112]               0
#         MaxPool2d-15           [-1, 64, 56, 56]               0
#         Dropout2d-16           [-1, 64, 56, 56]               0
#            Conv2d-17           [-1, 64, 56, 56]           2,112
#       BatchNorm2d-18           [-1, 64, 56, 56]             128
#            Conv2d-19          [-1, 128, 56, 56]          73,856
#       BatchNorm2d-20          [-1, 128, 56, 56]             256
#              ReLU-21          [-1, 128, 56, 56]               0
#            Conv2d-22          [-1, 128, 56, 56]         147,584
#       BatchNorm2d-23          [-1, 128, 56, 56]             256
#              ReLU-24          [-1, 128, 56, 56]               0
#         MaxPool2d-25          [-1, 128, 28, 28]               0
#         Dropout2d-26          [-1, 128, 28, 28]               0
#            Conv2d-27          [-1, 128, 28, 28]           8,320
#       BatchNorm2d-28          [-1, 128, 28, 28]             256
#            Conv2d-29          [-1, 256, 28, 28]         295,168
#       BatchNorm2d-30          [-1, 256, 28, 28]             512
#              ReLU-31          [-1, 256, 28, 28]               0
#            Conv2d-32          [-1, 256, 28, 28]         590,080
#       BatchNorm2d-33          [-1, 256, 28, 28]             512
#              ReLU-34          [-1, 256, 28, 28]               0
#         MaxPool2d-35          [-1, 256, 14, 14]               0
#         Dropout2d-36          [-1, 256, 14, 14]               0
#            Conv2d-37          [-1, 256, 14, 14]          33,024
#       BatchNorm2d-38          [-1, 256, 14, 14]             512
#            Conv2d-39          [-1, 512, 14, 14]       1,180,160
#       BatchNorm2d-40          [-1, 512, 14, 14]           1,024
#              ReLU-41          [-1, 512, 14, 14]               0
#            Conv2d-42          [-1, 512, 14, 14]       2,359,808
#       BatchNorm2d-43          [-1, 512, 14, 14]           1,024
#              ReLU-44          [-1, 512, 14, 14]               0
#         MaxPool2d-45            [-1, 512, 7, 7]               0
#         Dropout2d-46            [-1, 512, 7, 7]               0
#            Conv2d-47            [-1, 512, 7, 7]         131,584
#       BatchNorm2d-48            [-1, 512, 7, 7]           1,024
# AdaptiveAvgPool2d-49            [-1, 512, 1, 1]               0
#           Dropout-50                  [-1, 512]               0
#            Linear-51                  [-1, 256]         131,328
#              ReLU-52                  [-1, 256]               0
#           Dropout-53                  [-1, 256]               0
#            Linear-54                   [-1, 42]          10,794
# ================================================================
# Total params: 5,035,274
# Trainable params: 5,035,274
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 160.03
# Params size (MB): 19.21
# Estimated Total Size (MB): 179.81
# ----------------------------------------------------------------

# %% [markdown]
# ##Шаг 4. Функции для работы с моделью

# %% [markdown]
# #### Задание - напишите функции для работы с моделью

# %% [markdown]
# Обратите внимание, что метрика, которую необходимо оптимизировать в конкурсе -- `f1-score`.
#
# Ниже приводится код для вычисления целевой метрики.

# %%
from sklearn.metrics import f1_score
# пример расчета: f1 = f1_score(actual_labels, y_predicted, average='micro')

# %% [markdown]
# В этом задании может быть полезным сделать, чтобы функция валидации и, возможно, функция обучения на одной эпохе возвращали векторы/тензоры:
# - предсказанного наиболее вероятного класса
# - и фактических меток класса для каждого объекта.
#
# Сама метрика f1, при этом, будет вычисляться не внутри функции, а вне ее, сопоставляя прогнозные и фактические значения, полученные из вывода функции.
#
# Это поможет проанализировать, при предсказании каких классов модель ошибается чаще. Также такой подход может использоваться для обнаружения изображений, которые модель классифицирует неверно.

# %% [markdown]
# Для ускорения вычислений рекомендуется при работе с моделью проводить тензорные вычисления на GPU. Обращаем внимание, для этого необходимо, чтобы и данные, и модель находились на одном устройстве.
#
# Ниже представлен код из предыдущего домашнего задания, который демонстрировал логику циклов обучения и валидации. Ниже в этот код добавлены строки комментарии, показывающие как переносить модель и данные на устройство.
#
#
# ```python
# model.to(DEVICE)  # <- переносим модель на устройство DEVICE
#
# for epoch in range(max_epochs):
#     # режим train
#     model.train()
#     for x_batch, y_batch in train_dataloader:
#         x_batch.to(DEVICE)  # <- переносим тензоры данных на устройство DEVICE
#         y_batch.to(DEVICE)  # <- переносим тензоры данных на устройство DEVICE
#
#         optimizer.zero_grad()
#         outp = model(x_batch)
#         loss = criterion(outp, y_batch)
#         loss.backward()
#         optimizer.step()
#
#         count_metrics(outp, y_batch)  # <-здесь, скорее всего, потребуется перенести данные на cpu, например с помощью метода cpu: metrics.cpu()
#
#      # режим test/eval
#      model.eval()
#      for x_batch, y_batch in val_dataloader:
#         x_batch.to(DEVICE)  # <- переносим тензоры данных на устройство DEVICE
#         y_batch.to(DEVICE)  # <- переносим тензоры данных на устройство DEVICE
#
#         with torch.no_grad():
#             outp = model(x_batch)
#             count_metrics(outp, y_batch) # <-здесь, скорее всего, потребуется перенести данные на cpu
# ```

# %% [markdown]
# Напишите функции:
# - для обучения модели на одной эпохе
# - для валидации модели на одной эпохе
# - для реализации полного цикла обучения
#
# За основу можно взять функции, которые вы написали в предыдущем домашнем задании.

# %%
def fit_one_epoch(model, train_dataloader, optimizer, loss_func):
    '''
    args:
    model - модель для обучения
    train_dataloader - loader с выборкой для обучения модели
    optimizer - оптимизатор, взятый из модуля `torch.optim`
    loss_func - функция потерь, взятая из модуля `torch.nn`
    
    функция возвращает метрику accuracy по эпохе на данных из train_dataloader
    '''
    
    
    # YOUR CODE. переводим модель в режим train
    model.to(DEVICE)
    model.train()
    x = []
    y = []
    for X_batch, y_batch in tqdm(train_dataloader):
        # Далее далее по коду идут стандартные операции цикла обучения:
        # YOUR CODE. обнуляем градиенты модели
        X_batch = X_batch.to(DEVICE)
        y_batch = y_batch.to(DEVICE)
        optimizer.zero_grad()
        outp = model(X_batch) # YOUR CODE. Use model() to get outputs
        loss = loss_func(outp, y_batch)# YOUR CODE. Compute loss
    
        loss.backward()# YOUR CODE. считаем градиенты
        optimizer.step()# YOUR CODE. делаем шаг градиентного спуска
    
        # Рассчитаем accuracy. Для этого определим количество верных предсказаний
        # и общее количество предсказаний в каждом батче, а затем накопительным итогом посчитаем
        #  количество верных предсказаний и общее количество предсказаний в рамках эпохи
        preds = outp.argmax(-1)
        x.extend(preds.detach().cpu().tolist())
        y.extend(y_batch.detach().cpu().tolist())
    return [x,y]

# %%
def eval_one_epoch(model, val_dataloader):
    '''
    args:
    model - модель для обучения
    val_dataloader - loader с валидационной/тестовой выборкой
    '''
    x = []
    y = []
    # YOUR CODE. Переводим модель в режим eval
    model.to(DEVICE)
    model.eval()
    for X_batch, y_batch in tqdm(val_dataloader):
        X_batch = X_batch.to(DEVICE)
        y_batch = y_batch.to(DEVICE)
        # Далее далее по коду идут стандартные операции цикла валидации:
        # YOUR CODE. Не забываем отключить расчет градиентов
        with torch.no_grad():
          # YOUR CODE. Получаем "логиты" из модели
          logits = model(X_batch)
          preds = logits.argmax(-1)# YOUR CODE. Определяем нииболее вероятный класс для каждого объекта в батче
          
        x.extend(preds.detach().cpu().tolist())
        y.extend(y_batch.detach().cpu().tolist())
    return [x,y]

# %%
from torch.optim.lr_scheduler import ReduceLROnPlateau, CosineAnnealingLR, StepLR
def train_func(model, num_epochs, dataloaders, optimizer, loss_func, scheduler):
    '''
    args:
    model - модель для обучения
    num_epochs - количество эпох
    dataloaders - словарь loader'ов с обучающей и валидационной выборками
    optimizer - оптимизатор, взятый из модуля `torch.optim`
    loss_func - функция потерь, взятая из модуля `torch.nn`
    
    функция возвращает accuracy на обучающей и валидационной выборках на каждой эпохе
    '''
    
    f1 = {"train": [], "valid": []}
    tr = []
    val = []
    temp_f1 = 0
    for epoch in range(num_epochs):
        print(f"\nEpoch: {epoch+1}")
        
        train_one_epoch = fit_one_epoch(model = model, train_dataloader = dataloaders['train'], optimizer = optimizer, loss_func = loss_func)
        f1sc = f1_score(train_one_epoch[0], train_one_epoch[1], average='micro')
    
        if epoch >= num_epochs -1:
            tr.append([train_one_epoch])
    
      
        print(f"f1_train: {f1sc}\n")
    
        test_one_epoch = eval_one_epoch(model = model, val_dataloader = dataloaders['val'])
        f1scv = f1_score(test_one_epoch[0], test_one_epoch[1], average='micro')
        if epoch >= num_epochs -1:
            val.append([test_one_epoch])
        if temp_f1 < f1scv:
            temp_f1 = f1scv
            best_w = copy.deepcopy(model.state_dict())
            print('Сохранено!')

       
        scheduler.step(f1scv)
        new_lr = optimizer.param_groups[0]['lr']
        print(new_lr)
        print(f"f1_test: {f1scv}\n")
        f1['train'].append(f1sc)
        f1['valid'].append(f1scv)
    if temp_f1 != 0: 
        model.load_state_dict(best_w)
    return [f1, tr, val]

# %% [markdown]
# ## Шаг 5. Применение модели к данным

# %% [markdown]
# #### Применение модели к данным

# %% [markdown]
# Запустите обучение сети

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model_simple_cnn.parameters(), lr = 3e-3, weight_decay = 3e-4)
scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=3)
f1 = train_func(model = model_simple_cnn, num_epochs = 20, dataloaders = loaders,optimizer = optimizer, loss_func= criterion, scheduler = scheduler)
#Обучение слетело, но модель показала точность 96% за 40 эпох и могла обучаться дальше, заново обучил только на 20 
#чтобы не терять время, т.к. предобученная модель показала результат гораздо лучше за меньшее время
# Out:
# Epoch: 1
# 100%|██████████| 246/246 [01:38<00:00,  2.50it/s]
# f1_train: 0.08013249251544684
# 100%|██████████| 82/82 [00:12<00:00,  6.83it/s]
# Сохранено!
# 0.003
# f1_test: 0.04088651127244937
#
#
# Epoch: 2
# 100%|██████████| 246/246 [01:50<00:00,  2.22it/s]
# f1_train: 0.15720746544365882
# 100%|██████████| 82/82 [00:12<00:00,  6.56it/s]
# Сохранено!
# 0.003
# f1_test: 0.08215513947267863
#
#
# Epoch: 3
# 100%|██████████| 246/246 [01:51<00:00,  2.21it/s]
# f1_train: 0.22778520924899676
# 100%|██████████| 82/82 [00:12<00:00,  6.72it/s]
# Сохранено!
# 0.003
# f1_test: 0.13412304165074512
#
#
# Epoch: 4
# 100%|██████████| 246/246 [01:51<00:00,  2.20it/s]
# f1_train: 0.29027326581310914
# 100%|██████████| 82/82 [00:12<00:00,  6.60it/s]
# Сохранено!
# 0.003
# f1_test: 0.20787160871226595
#
#
# Epoch: 5
# 100%|██████████| 246/246 [01:51<00:00,  2.20it/s]
# f1_train: 0.3799605070386649
# 100%|██████████| 82/82 [00:12<00:00,  6.60it/s]
# Сохранено!
# 0.003
# f1_test: 0.3354986625907528
#
#
# Epoch: 6
# 100%|██████████| 246/246 [01:51<00:00,  2.21it/s]
# f1_train: 0.4560163067711319
# 100%|██████████| 82/82 [00:12<00:00,  6.63it/s]
# Сохранено!
# 0.003
# f1_test: 0.4172716851356515
#
#
# Epoch: 7
# 100%|██████████| 246/246 [01:51<00:00,  2.21it/s]
# f1_train: 0.5263392572775336
# 100%|██████████| 82/82 [00:12<00:00,  6.59it/s]
# Сохранено!
# 0.003
# f1_test: 0.42873519296904855
#
#
# Epoch: 8
# 100%|██████████| 246/246 [01:51<00:00,  2.21it/s]
# f1_train: 0.6022039620357985
# 100%|██████████| 82/82 [00:12<00:00,  6.50it/s]
# Сохранено!
# 0.003
# f1_test: 0.5298051203668322
#
#
# Epoch: 9
# 100%|██████████| 246/246 [01:51<00:00,  2.21it/s]
# f1_train: 0.6622077839352825
# 100%|██████████| 82/82 [00:13<00:00,  6.21it/s]
# Сохранено!
# 0.003
# f1_test: 0.6213221245701185
#
#
# Epoch: 10
# 100%|██████████| 246/246 [01:51<00:00,  2.21it/s]
# f1_train: 0.7110007006815721
# 100%|██████████| 82/82 [00:12<00:00,  6.53it/s]
# Сохранено!
# 0.003
# f1_test: 0.6404279709591135
#
#
# Epoch: 11
# 100%|██████████| 246/246 [01:51<00:00,  2.20it/s]
# f1_train: 0.7503662653672208
# 100%|██████████| 82/82 [00:12<00:00,  6.71it/s]
# Сохранено!
# 0.003
# f1_test: 0.7248758119984715
#
#
# Epoch: 12
# 100%|██████████| 246/246 [01:51<00:00,  2.21it/s]
# f1_train: 0.7794763997706861
# 100%|██████████| 82/82 [00:12<00:00,  6.70it/s]
# 0.003
# f1_test: 0.7199082919373329
#
#
# Epoch: 13
# 100%|██████████| 246/246 [01:51<00:00,  2.21it/s]
# f1_train: 0.8094783107204281
# 100%|██████████| 82/82 [00:12<00:00,  6.45it/s]
# Сохранено!
# 0.003
# f1_test: 0.7430263660680169
#
#
# Epoch: 14
# 100%|██████████| 246/246 [01:51<00:00,  2.21it/s]
# f1_train: 0.8304987578826677
# 100%|██████████| 82/82 [00:12<00:00,  6.45it/s]
# Сохранено!
# 0.003
# f1_test: 0.8131448223156286
#
#
# Epoch: 15
# 100%|██████████| 246/246 [01:51<00:00,  2.21it/s]
# f1_train: 0.8505637301738964
# 100%|██████████| 82/82 [00:12<00:00,  6.58it/s]
# Сохранено!
# 0.003
# f1_test: 0.8259457393962553
#
#
# Epoch: 16
# 100%|██████████| 246/246 [01:51<00:00,  2.21it/s]
# f1_train: 0.8701191158672527
# 100%|██████████| 82/82 [00:12<00:00,  6.72it/s]
# Сохранено!
# 0.003
# f1_test: 0.8364539549102025
#
#
# Epoch: 17
# 100%|██████████| 246/246 [01:50<00:00,  2.22it/s]
# f1_train: 0.870437607490923
# 100%|██████████| 82/82 [00:12<00:00,  6.52it/s]
# 0.003
# f1_test: 0.8175391669850974
#
#
# Epoch: 18
# 100%|██████████| 246/246 [01:51<00:00,  2.21it/s]
# f1_train: 0.8826676858398624
# 100%|██████████| 82/82 [00:12<00:00,  6.54it/s]
# Сохранено!
# 0.003
# f1_test: 0.838555598012992
#
#
# Epoch: 19
# 100%|██████████| 246/246 [01:50<00:00,  2.22it/s]
# f1_train: 0.8975730938276323
# 100%|██████████| 82/82 [00:12<00:00,  6.68it/s]
# Сохранено!
# 0.003
# f1_test: 0.8530760412686282
#
#
# Epoch: 20
# 100%|██████████| 246/246 [01:51<00:00,  2.21it/s]
# f1_train: 0.906936747563539
# 100%|██████████| 82/82 [00:12<00:00,  6.57it/s]
# Сохранено!
# 0.003
# f1_test: 0.8687428353076041

# %% [markdown]
# # Дообучение efficientnet
# # Данных много, поэтому будем тренировать модель полностью

# %%
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision.models import EfficientNet_B3_Weights

# 1. Загрузка
weights = EfficientNet_B3_Weights.DEFAULT
model = models.efficientnet_b3(weights=weights)
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_b3_rwightman-b3899882.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b3_rwightman-b3899882.pth
# 100%|██████████| 47.2M/47.2M [00:00<00:00, 181MB/s]

# %%
print(model)
# Out:
# EfficientNet(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#             (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(4, 16, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.008695652173913044, mode=row)
#       )
#     )
#     (2): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.017391304347826087, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.026086956521739136, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.034782608695652174, mode=row)
#       )
#     )
#     (3): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(144, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.043478260869565216, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288, bias=False)
#             (1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05217391304347827, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288, bias=False)
#             (1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.06086956521739131, mode=row)
#       )
#     )
#     (4): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(288, 288, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=288, bias=False)
#             (1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(288, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.06956521739130435, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(528, 528, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=528, bias=False)
#             (1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(528, 22, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(22, 528, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(528, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0782608695652174, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(528, 528, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=528, bias=False)
#             (1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(528, 22, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(22, 528, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(528, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08695652173913043, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(528, 528, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=528, bias=False)
#             (1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(528, 22, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(22, 528, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(528, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.09565217391304348, mode=row)
#       )
#     )
#     (5): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(528, 528, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=528, bias=False)
#             (1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(528, 22, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(22, 528, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(528, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.10434782608695654, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(720, 720, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=720, bias=False)
#             (1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(720, 30, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(30, 720, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(720, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.11304347826086956, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(720, 720, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=720, bias=False)
#             (1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(720, 30, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(30, 720, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(720, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.12173913043478261, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(720, 720, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=720, bias=False)
#             (1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(720, 30, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(30, 720, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(720, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.13043478260869565, mode=row)
#       )
#     )
#     (6): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(720, 720, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=720, bias=False)
#             (1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(720, 30, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(30, 720, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(720, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1391304347826087, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1248, 1248, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1248, bias=False)
#             (1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.14782608695652175, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1248, 1248, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1248, bias=False)
#             (1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1565217391304348, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1248, 1248, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1248, bias=False)
#             (1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.16521739130434784, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1248, 1248, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1248, bias=False)
#             (1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17391304347826086, mode=row)
#       )
#     )
#     (7): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1248, 1248, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1248, bias=False)
#             (1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1248, 352, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1826086956521739, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(352, 2112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2112, 2112, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2112, bias=False)
#             (1): BatchNorm2d(2112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2112, 88, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(88, 2112, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2112, 352, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.19130434782608696, mode=row)
#       )
#     )
#     (8): Conv2dNormActivation(
#       (0): Conv2d(352, 1408, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1408, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Dropout(p=0.3, inplace=True)
#     (1): Linear(in_features=1408, out_features=1000, bias=True)
#   )
# )

# %%
#требуется изменить только классификатор
n_classes = len(np.unique(train_val_labels))
in_ftrs = model.classifier[1].in_features

#модель училась на imagenet с большим количеством классов, поэтому решил чуть-чуть сократить, Чтобы не прыгать сразу от 1500 параметров к 3

model.classifier = nn.Sequential( 
    nn.Dropout(0.2, inplace=True),
    nn.Linear(in_ftrs, in_ftrs//2),
    nn.Dropout(0.2, inplace=True),
    nn.Linear(in_ftrs//2, in_ftrs//2),
    nn.Dropout(0.2, inplace=True),
    nn.Linear(in_ftrs//2, n_classes),
)

model = model.to(DEVICE)
#можно переделать преобразования картинок под модель (есть встроенный список преобразований),
#но я не стал, потому что модель уже на первой эпохе показала результат в 0.94

# %%
optimizer = torch.optim.AdamW(model.parameters(), lr=3e-5, weight_decay=3e-4) # поставил маленький lr
criterion = nn.CrossEntropyLoss()
scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=3)


effout = train_func(model, 15, loaders, optimizer, criterion, scheduler) 
#стоило бы усилить аугментацию, и переобучить, но ломалась бы написанная ранее модель,
#потому что не потянула бы слишком сильной аугментации, пришлось бы гораздо дольше учить
# Out:
# Epoch: 1
# 100%|██████████| 246/246 [03:00<00:00,  1.36it/s]
# f1_train: 0.3209758583349258
# 100%|██████████| 82/82 [00:15<00:00,  5.26it/s]
# Сохранено!
# 3e-05
# f1_test: 0.5032479938861292
#
#
# Epoch: 2
# 100%|██████████| 246/246 [02:59<00:00,  1.37it/s]
# f1_train: 0.8054653162621823
# 100%|██████████| 82/82 [00:15<00:00,  5.25it/s]
# Сохранено!
# 3e-05
# f1_test: 0.8926251432938479
#
#
# Epoch: 3
# 100%|██████████| 246/246 [02:59<00:00,  1.37it/s]
# f1_train: 0.9345181221733868
# 100%|██████████| 82/82 [00:15<00:00,  5.27it/s]
# Сохранено!
# 3e-05
# f1_test: 0.92338555598013
#
#
# Epoch: 4
# 100%|██████████| 246/246 [02:59<00:00,  1.37it/s]
# f1_train: 0.9596152621186063
# 100%|██████████| 82/82 [00:15<00:00,  5.24it/s]
# Сохранено!
# 3e-05
# f1_test: 0.938479174627436
#
#
# Epoch: 5
# 100%|██████████| 246/246 [02:59<00:00,  1.37it/s]
# f1_train: 0.9718453404675457
# 100%|██████████| 82/82 [00:15<00:00,  5.28it/s]
# Сохранено!
# 3e-05
# f1_test: 0.9476499808941536
#
#
# Epoch: 6
# 100%|██████████| 246/246 [02:59<00:00,  1.37it/s]
# f1_train: 0.9787247595388241
# 100%|██████████| 82/82 [00:15<00:00,  5.24it/s]
# Сохранено!
# 3e-05
# f1_test: 0.9558654948414215
#
#
# Epoch: 7
# 100%|██████████| 246/246 [02:59<00:00,  1.37it/s]
# f1_train: 0.9819733741002612
# 100%|██████████| 82/82 [00:15<00:00,  5.29it/s]
# Сохранено!
# 3e-05
# f1_test: 0.9583492548719909
#
#
# Epoch: 8
# 100%|██████████| 246/246 [02:59<00:00,  1.37it/s]
# f1_train: 0.9857952735843047
# 100%|██████████| 82/82 [00:15<00:00,  5.26it/s]
# Сохранено!
# 3e-05
# f1_test: 0.9640810087886893
#
#
# Epoch: 9
# 100%|██████████| 246/246 [02:59<00:00,  1.37it/s]
# f1_train: 0.9902541563156889
# 100%|██████████| 82/82 [00:15<00:00,  5.24it/s]
# Сохранено!
# 3e-05
# f1_test: 0.965227359572029
#
#
# Epoch: 10
# 100%|██████████| 246/246 [03:00<00:00,  1.37it/s]
# f1_train: 0.9895534747436142
# 100%|██████████| 82/82 [00:15<00:00,  5.25it/s]
# Сохранено!
# 3e-05
# f1_test: 0.9665647688192587
#
#
# Epoch: 11
# 100%|██████████| 246/246 [02:59<00:00,  1.37it/s]
# f1_train: 0.9918466144340404
# 100%|██████████| 82/82 [00:15<00:00,  5.25it/s]
# Сохранено!
# 3e-05
# f1_test: 0.9679021780664884
#
#
# Epoch: 12
# 100%|██████████| 246/246 [03:00<00:00,  1.37it/s]
# f1_train: 0.9915281228103701
# 100%|██████████| 82/82 [00:15<00:00,  5.27it/s]
# Сохранено!
# 3e-05
# f1_test: 0.969430645777608
#
#
# Epoch: 13
# 100%|██████████| 246/246 [02:59<00:00,  1.37it/s]
# f1_train: 0.9921014077329766
# 100%|██████████| 82/82 [00:15<00:00,  5.25it/s]
# 3e-05
# f1_test: 0.969430645777608
#
#
# Epoch: 14
# 100%|██████████| 246/246 [02:59<00:00,  1.37it/s]
# f1_train: 0.993630167526594
# 100%|██████████| 82/82 [00:15<00:00,  5.27it/s]
# Сохранено!
# 3e-05
# f1_test: 0.9721054642720672
#
#
# Epoch: 15
# 100%|██████████| 246/246 [02:59<00:00,  1.37it/s]
# f1_train: 0.9952863239696796
# 100%|██████████| 82/82 [00:15<00:00,  5.24it/s]
# Сохранено!
# 3e-05
# f1_test: 0.9742071073748567

# %% [markdown]
# #  На 15 эпохе модель получила метрику f1 = 0.974

# %%
torch.save(model.state_dict(), 'model_weights.pth')
torch.save(model, 'full_model.pth')

# %% [markdown]
# (опционально) Постройте график динамики метрик модели по ходу обучения

# %%
import matplotlib.pyplot as plt


plt.plot(effout[0]['train'], label='Train')
plt.plot(effout[0]['valid'], label='Valid')
plt.legend()
plt.show()

# %%
with torch.no_grad():
    test_one_epoch = eval_one_epoch(model = model, val_dataloader = loaders['val'])
    
f1scvv = f1_score(test_one_epoch[0], test_one_epoch[1], average='micro')
# Out:
# 100%|██████████| 82/82 [00:16<00:00,  5.05it/s]

# %%
f1scvv
# Out:
# 0.9742071073748567

# %% [markdown]
# # Итоговый f1 score: 0.974

# %% [markdown]
# ### Ну и что теперь со всем этим делать?

# %% [markdown]
# ![alt text](https://www.indiewire.com/wp-content/uploads/2014/08/the-simpsons.jpg)

# %% [markdown]
# Сделаем классную визуализацию,  чтобы посмотреть насколько сеть уверена в своих ответах.

# %%
import matplotlib.patches as patches
from matplotlib.font_manager import FontProperties

@torch.no_grad()
def show_images2(n_rows, n_cols, dataset, model):
  # функция выводит изображения в n_rows рядов и n_cols столбцов
  fig, axs = plt.subplots(nrows=n_rows, ncols=n_cols, figsize=(n_cols * 4, n_rows * 4), \
                        sharey=True, sharex=True)

  for fig_x in axs.flatten(): # цикл повторяется (n_rows * n_cols) раз
    random_characters = int(np.random.uniform(0, len(dataset))) # берем случайное число в диапазоне [0; len(dataset))
    im_val, label = dataset[random_characters] # выводим изображение (тензорная форма)
    img_label = " ".join(map(lambda x: x.capitalize(), \
                             label_encoder.inverse_transform([label])[0].split('_')))  # числовую метку класса преобразуем в текстовую и немного отформатируем
    imshow(im_val.data.cpu(), title=img_label, plt_ax=fig_x) # отобразим изображение и метку класса с помощью написанной ранее функции imshow()

    # ниже представлен код для добавления на изображение подписи с вероятностью класса
    actual_text = "Actual : {}".format(img_label)


    font0 = FontProperties()
    font = font0.copy()

    # наша модель возвращает логиты, поэтому для получения вероятностей классов не забываем применить softmax:
    prob_pred = nn.functional.softmax(model(im_val.unsqueeze(0).to(DEVICE)), dim = -1).cpu().numpy()

    predicted_proba = np.max(prob_pred)*100 # берем максимальную вероятность класса
    y_pred = np.argmax(prob_pred) # берем числовую метку класса, для которого вероятность максимальна

    predicted_label = " ".join(map(lambda x: x.capitalize(), \
                             label_encoder.inverse_transform([y_pred])[0].split('_')))
    predicted_text = "{}:\n {:.1f}%".format(predicted_label, predicted_proba)

    fig_x.add_patch(patches.Rectangle((0, 190), 7*len(predicted_label), 25,color='white'))
    fig_x.text(2, 195, predicted_text , horizontalalignment='left', fontproperties=font,
                    verticalalignment='top',fontsize=8, color='black',fontweight='bold')
    fig_x.set_axis_off()

  return None

# %%
show_images2(n_rows = 4, n_cols = 4, dataset = val_dataset, model = model_simple_cnn)

# %% [markdown]
# ## Шаг 6. Submit на Kaggle

# %% [markdown]
# ![alt text](https://i.redd.it/nuaphfioz0211.jpg)

# %% [markdown]
# Создадим loader для тестовых данных

# %%
test_dataset = SimpsonsDataset(test_files, label_encoder = label_encoder, mode="test")
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=64)

# %% [markdown]
# Воспользуемся функцией predict, которая возвращает предсказанные числовые метки для всех объектов в лоадере.

# %%
def predict(model, loader):
    model.eval()
    all_predictions = torch.tensor([]).to(DEVICE).int()
    print("Test mode...")
    for inputs in tqdm_notebook(loader):
        inputs = inputs.to(DEVICE)

        with torch.no_grad():
            outputs = model(inputs)

            predictions = outputs.argmax(-1).int()
            all_predictions = torch.cat((all_predictions, predictions), 0)
    return all_predictions.cpu()

# %% [markdown]
# Получем предсказание меток классов для тестовых данных:

# %%
predicted_numeric_labels = predict(model, test_loader)
# Out:
# Test mode...
#   0%|          | 0/16 [00:00<?, ?it/s]

# %% [markdown]
# и преобразуем их в текстовые метки:

# %%
predicted_text_labels = label_encoder.inverse_transform(predicted_numeric_labels)

# %% [markdown]
# Загрузим пример файла для загрузки на Kaggle (проверьте путь, по которому у вас лежит файл sample_submission.csv и при необходимости скорректируйте путь в коде ниже):

# %%
import pandas as pd
sample_submission = pd.read_csv("/kaggle/working/sample_submission.csv")
sample_submission.head(10)
# Out:
#          Id      Expected
# 0  img0.jpg  bart_simpson
# 1  img1.jpg  bart_simpson
# 2  img2.jpg  bart_simpson
# 3  img3.jpg  bart_simpson
# 4  img4.jpg  bart_simpson
# 5  img5.jpg  bart_simpson
# 6  img6.jpg  bart_simpson
# 7  img7.jpg  bart_simpson
# 8  img8.jpg  bart_simpson
# 9  img9.jpg  bart_simpson

# %%
my_submission = pd.DataFrame({'Id': [path.name for path in test_files], 'Expected': predicted_text_labels})
my_submission.head(10)
# Out:
#            Id                Expected
# 0    img0.jpg            nelson_muntz
# 1    img1.jpg            bart_simpson
# 2   img10.jpg            ned_flanders
# 3  img100.jpg            chief_wiggum
# 4  img101.jpg  apu_nahasapeemapetilon
# 5  img102.jpg           kent_brockman
# 6  img103.jpg          edna_krabappel
# 7  img104.jpg            chief_wiggum
# 8  img105.jpg            lisa_simpson
# 9  img106.jpg           kent_brockman

# %%
# TODO : сделайте сабмит (это важно, если Вы не справляетесь, но дошли до этой ячейки, то сообщите в чат и Вам помогут)

# %%
my_submission.to_csv('cnnanswwww.csv', index=False)

# %% [markdown]
# ## Приключение?
#
# А теперь самое интересное, мы сделали простенькую сверточную сеть и смогли отправить сабмит, но получившийся score нас явно не устраивает. Надо с этим что-то сделать.
#
# Вам предлагается творческая и исследовательская свобода в том, как вы будете улучшать score модели. Вот некоторые направления, которые вы, возможно, захотите попробовать:
# 1. Работа с датасетом:
# * Попробуйте увеличить разнообразие обучающей выборки при помощи аугментации ([ссылка 1](https://habr.com/ru/companies/smartengines/articles/264677/), [ссылка 2](https://www.geeksforgeeks.org/python-data-augmentation/));
# * Используя результаты функции eval_one_epoch, вы можете посмотреть, как метрика f1-score внутри класса связана с размером самого класса в обучающей выборке. Скорее всего, вы заметите прямую зависимость. Решением может быть увеличение размеров слабо представленных классов. Сделать это можно, вручную добавив этот функционал в SimpsonsDataset или воспользовавшись инструментом WeightedRandomSampler.
#
# * Также вы можете изучить, какие изображения модель классифицирует неверно. Можно просто посмотреть неверно классифицированные изображения в валидационном датасете. Можно попробовать более фундаментальный подход - создать dataloader из всех изображений обучающей и валидационной выборки в SimpsonsDataset c режимом 'val', прогнать данные через обученную модель simple_cnn. Более того, можно обучить несколько моделей с разной архитектурой, и прогнать объединенный датасет через все эти модели - и выделить те изображения, в классификации которых ошиблись несколько моделей.
#
# * Это поможет понять, как качество и чистота исходных данных влияет на результаты обучения модели. Если вы обнаружите ошибки в simpsons_dataset и решите их исправить или удалить некоторые изображения из обучающей выборки - сделайте это в ноутбуке, чтобы при проверке можно было повторить результаты работы вашего кода.
#
# 2. Работа с архитектурой сети:
# * учим дольше и изменяем (подбираем) гиперпараметры: learning rate, batch size, нормализация картинки и вот это всё;
# * добавление/удаление свёрточных и полносвязных слоёв;
# * А еще есть где пулинги и батч-норм!
#
# 3. Применение техник, описанных в предыдущих пунктах, позволяет добиться довольно высоких результатов. Но вы можете попробовать файнтютинг и трансферлёнинг:
# * ну разве это deep learning? Вот ResNet и Inception, которые можно зафайнтьюнить под наши данные, вот это я понимаю (можно и обучить в колабе, а можно и [готовые](https://github.com/Cadene/pretrained-models.pytorch) скачать).
#
# 4. Улучшение оптимизации:
# * ну разве Адам наше все? [adamW](https://www.fast.ai/2018/07/02/adam-weight-decay/) для практика, [статейка для любителей](https://openreview.net/pdf?id=ryQu7f-RZ) (очень хороший анализ), [наши ](https://github.com/MichaelKonobeev/adashift/) эксперименты для заинтересованных.
#
# 5. Наконец, возможно, стоит подумать об ансамблях
#
#
# Надеюсь, что у Вас получится!

# %% [markdown]
# # Итоговое качество:
# # в ноутбуке: f1 = 0.974
# # на kaggle: f1 = 0.993

# %%
f1scvv
# Out:
# 0.9742071073748567
